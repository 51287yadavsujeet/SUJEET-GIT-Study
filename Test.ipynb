# %% [markdown]
# <a href="https://colab.research.google.com/github/51287yadavsujeet/SUJEET-GIT-Study/blob/master/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(1+1)
# Out:
# 2

# %%
print(1+1)
# Out:
# 2
